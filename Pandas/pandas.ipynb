# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.0'

# %% [markdown]
# Creating DataFrames

# %%
df = pd.DataFrame([11,22,33,44], columns=['col_name'])
df
print(type(df)) # printing type of dataframe
# Out:
# <class 'pandas.DataFrame'>

# %%
data = {
    'name':['a','b','c','d','e'],
    'Age':[16,17,18,19,20],
    'Salary':[100000,200000,300000,400000,500000]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   name  Age  Salary
# 0    a   16  100000
# 1    b   17  200000
# 2    c   18  300000
# 3    d   19  400000
# 4    e   20  500000

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# Basic Understanding thing

# %%
df.head(2)
# Out:
#   name  Age  Salary
# 0    a   16  100000
# 1    b   17  200000

# %%
df.tail(2)
# Out:
#   name  Age  Salary
# 3    d   19  400000
# 4    e   20  500000

# %%
df.shape
# Out:
# (5, 3)

# %%
df.size
# Out:
# 15

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      str
#  1   Age     5 non-null      int64
#  2   Salary  5 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 252.0 bytes

# %%
df.describe()
# Out:
#              Age         Salary
# count   5.000000       5.000000
# mean   18.000000  300000.000000
# std     1.581139  158113.883008
# min    16.000000  100000.000000
# 25%    17.000000  200000.000000
# 50%    18.000000  300000.000000
# 75%    19.000000  400000.000000
# max    20.000000  500000.000000

# %%
df.columns
# Out:
# Index(['name', 'Age', 'Salary'], dtype='str')

# %%
df.dtypes
# Out:
# name        str
# Age       int64
# Salary    int64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.rename(columns={'salary':'Monthely_salary'},inplace=True)

# %%
df.to_csv('pandas_practice_file.csv',index=False) #export dataframe

# %%
load_df = pd.read_csv('pandas_practice_file.csv') # import dataframe

# %% [markdown]
# Row column Selction

# %%
df[['name','Salary']]
# Out:
#   name  Salary
# 0    a  100000
# 1    b  200000
# 2    c  300000
# 3    d  400000
# 4    e  500000

# %%
df.loc[df.name == 'a']  # label based indexing
df.loc[(df.name == 'a') & (df.Salary>=40000)]
# Out:
#   name  Age  Salary
# 0    a   16  100000

# %%
df.iloc[0] # index-value based 
df.iloc[0:2]
# Out:
#   name  Age  Salary
# 0    a   16  100000
# 1    b   17  200000
