# %% [markdown]
# # Main heading
# ## subheading
# ### small heading
#  this regular text
#
#  ---
# - task list 1
# - task list 2

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# This markdown cell

# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
