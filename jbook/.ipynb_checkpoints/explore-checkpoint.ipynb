# %% [markdown]
# # Main heading
# ## subheading
# ### small heading
#  this regular text
#
#  ---
# - task list 1
# - task list 2

# %%
print("hello")
# Out:
# The kernel failed to start as the Python Environment 'Python 3.12.4' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
print("hello")
