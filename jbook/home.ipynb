# %% [markdown]
# # welcome to chai code

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello again")
# Out:
# Running cells with '.venv (3.12.4) (Python 3.12.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/python_hitesh choudhary/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
print("sandeep")

# %%
print("sandeep")

# %%
print("sandeep")

# %% [markdown]
# djgfhjgsdfhash

# %%
print("sandeep sharam")

# %%
print("sadee")

# %%
1+1
